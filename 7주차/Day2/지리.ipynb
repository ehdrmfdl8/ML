# %%
import googlemaps
import googlemap_key
gmaps = googlemaps.Client(key=googlemap_key.gmaps_key)

# %%
gmaps.geocode('서울중부경찰서', language='ko')
# Out:
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# c:\users\sigel\appdata\local\programs\python\python36-32\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# c:\users\sigel\appdata\local\programs\python\python36-32\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ...

# %%
def getAddr(name):
    map = gmaps.geocode(name, language='ko')
    addr = map[0].get('formatted_address')
    tmp_loc = map[0].get('geometry').get('location')
    return addr, tmp_loc['lat'], tmp_loc['lng']

# %%
addr, lat, lng = getAddr('중부경찰서')
print(addr, lat, lng)

# %%
Seoul_loc = getAddr('서울시')[1:]
# Out:
# ---------------------------------------------------------------------------
# _RetriableRequest                         Traceback (most recent call last)
# c:\users\sigel\appdata\local\programs\python\python36-32\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     252             else:
# --> 253                 result = self._get_body(response)
#     254             self.sent_times.append(time.time())
#
# c:\users\sigel\appdata\local\programs\python\python36-32\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     275         if api_status == "OVER_QUERY_LIMIT":
# --> 276             raise googlemaps.exceptions._RetriableRequest()
#     277
#
# _RetriableRequest:
#
# During handling of the above exception, another exception occurred:
#
# _RetriableRequest                         Traceback (most recent call last)
# ...

# %%
Seoul_loc = [37.5662952, 126.9779451]

# %%
import folium
map = folium.Map(location = Seoul_loc)
map.save('c:/python/html/Seoul.html') #별도 html로 저장할 때
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = Seoul_loc, zoom_start = 13)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = Seoul_loc, zoom_start = 13, tiles = 'Stamen Toner')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = Seoul_loc, zoom_start = 15)
folium.Marker(Seoul_loc, popup='서울특별시청').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = Seoul_loc, zoom_start = 15)
folium.Marker(Seoul_loc, popup='서울특별시청', 
              icon=folium.Icon(icon='cloud', color = 'red')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = Seoul_loc, zoom_start = 15)
folium.CircleMarker(Seoul_loc, radius = 50, popup = '서울특별시청', fill = True,
                    color = '#3186cc', fill_color = '#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
geo_str = json.load(open('Seoul_geo.json', encoding = 'utf-8'))
map = folium.Map(location = Seoul_loc, zoom_start = 11)
map.choropleth(geo_data = geo_str, fill_opacity = 0.3, fill_color = 'red')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
